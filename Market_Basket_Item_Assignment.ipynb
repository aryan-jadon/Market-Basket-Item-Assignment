# %% [markdown]
# ## Association Rule Learning
#
# In machine learning, association rule learning is a method of finding interesting relationships between the variables in a large dataset. This concept is mainly used by supermarkets and multipurpose e-commerce websites. Where it is used for defining the patterns of selling different products. More formally we can say it is useful to extract strong riles from a large database using any measure of interestingness.

# %%
''' importing libraries '''
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori,association_rules

# %%
''' reading dataset '''
data_frame = pd.read_csv('https://raw.githubusercontent.com/aryan-jadon/Market-Basket-Item-Assignment/main/Dataset/TRAIN-ARULES.csv')
data_frame.product_name = ["".join(i.split(",")) for i in data_frame.product_name]
orders = data_frame.order_id.unique()

# %%
''' checking shape '''
orders.shape
# Out:
# (1418,)

# %%
''' data transformation '''
transactions = [data_frame[data_frame.order_id == i]["product_name"].tolist() for i in orders]
trans_encoder = TransactionEncoder().fit(transactions)
transactions = trans_encoder.transform(transactions)
transactions = pd.DataFrame(transactions,columns=trans_encoder.columns_)

# %%
transactions.head(5)
# Out:
#    0% Fat Free Organic Milk  ...  smartwater® Electrolyte Enhanced Water
# 0                     False  ...                                   False
# 1                     False  ...                                   False
# 2                     False  ...                                   False
# 3                     False  ...                                   False
# 4                     False  ...                                   False
#
# [5 rows x 3540 columns]

# %%
''' using apriori algorithm '''
freq_itemset_using_apriori = apriori(transactions, min_support = 0.01, use_colnames = True)
association_rules_using_apriori = association_rules(freq_itemset_using_apriori, metric = "confidence")

# %%
print("Association Rules using Apriori Method:- \n")
for item in association_rules_using_apriori.iterrows():
  print(f"Rule {item[0] + 1}: {tuple(item[1].antecedents)} -> {tuple(item[1].consequents)}")
# Out:
# Association Rules using Apriori Method:-
#
# Rule 1: ('Authentic French Brioche',) -> ('Petit Suisse Fruit',)
# Rule 2: ('Petit Suisse Fruit',) -> ('Authentic French Brioche',)
# Rule 3: ('Oatmeal Crème Pies',) -> ('Cran-Apple Juice Drink',)
# Rule 4: ('Cran-Apple Juice Drink',) -> ('Oatmeal Crème Pies',)
# Rule 5: ('Sparkling Water Natural Mango Essenced',) -> ('Dark Chocolate Minis',)
# Rule 6: ('Grade A Extra Large Eggs',) -> ('Natural Lime Flavor Sparkling Mineral Water',)
# Rule 7: ('Lemon Sparkling Water',) -> ('Orange Sparkling Water',)
# Rule 8: ('Light Oaked Chardonnay',) -> ('Natural Lime Flavor Sparkling Mineral Water',)
# Rule 9: ('Reduced Fat Milk',) -> ('Natural Artesian Bottled Water',)
# Rule 10: ('Organic Graham Crunch Cereal',) -> ('Organic Heritage Flakes Cereal',)
# Rule 11: ('Sparkling Water Natural Mango Essenced',) -> ('Organic Pink Lemonade Bunny Fruit Snacks',)
# Rule 12: ('Sparkling Water Natural Mango Essenced',) -> ('Peach-Pear Sparkling Water',)
# Rule 13: ('Zero Calorie Cola',) -> ('Soda',)
# Rule 14: ('Total 0% Raspberry Yogurt',) -> ('Total 2% with Strawberry Lowfat Greek Strained Yogurt',)
# Rule 15: ('Total 2% Lowfat Greek Strained Yogurt With Blueberry',) -> ('Total 2% with Strawberry Lowfat Greek Strained Yogurt',)
# Rule 16: ('Peach-Pear Sparkling Water', 'Dark Chocolate Minis') -> ('Organic Pink Lemonade Bunny Fruit Snacks',)
# Rule 17: ('Peach-Pear Sparkling Water', 'Organic Pink Lemonade Bunny Fruit Snacks') -> ('Dark Chocolate Minis',)
# Rule 18: ('Sparkling Water Natural Mango Essenced', 'Dark Chocolate Minis') -> ('Organic Pink Lemonade Bunny Fruit Snacks',)
# Rule 19: ('Sparkling Water Natural Mango Essenced', 'Organic Pink Lemonade Bunny Fruit Snacks') -> ('Dark Chocolate Minis',)
# Rule 20: ('Sparkling Water Natural Mango Essenced',) -> ('Dark Chocolate Minis', 'Organic Pink Lemonade Bunny Fruit Snacks')
# Rule 21: ('Peach-Pear Sparkling Water', 'Sparkling Water Natural Mango Essenced') -> ('Dark Chocolate Minis',)
# Rule 22: ('Peach-Pear Sparkling Water', 'Dark Chocolate Minis') -> ('Sparkling Water Natural Mango Essenced',)
# Rule 23: ('Sparkling Water Natural Mango Essenced', 'Dark Chocolate Minis') -> ('Peach-Pear Sparkling Water',)
# Rule 24: ('Sparkling Water Natural Mango Essenced',) -> ('Peach-Pear Sparkling Water', 'Dark Chocolate Minis')
# Rule 25: ('Natural Lime Flavor Sparkling Mineral Water', 'Light Oaked Chardonnay') -> ('Grade A Extra Large Eggs',)
# Rule 26: ('Grade A Extra Large Eggs', 'Light Oaked Chardonnay') -> ('Natural Lime Flavor Sparkling Mineral Water',)
# Rule 27: ('Peach-Pear Sparkling Water', 'Organic Heritage Flakes Cereal') -> ('Organic Pink Lemonade Bunny Fruit Snacks',)
# Rule 28: ('Peach-Pear Sparkling Water', 'Sparkling Water Natural Mango Essenced') -> ('Organic Pink Lemonade Bunny Fruit Snacks',)
# Rule 29: ('Peach-Pear Sparkling Water', 'Organic Pink Lemonade Bunny Fruit Snacks') -> ('Sparkling Water Natural Mango Essenced',)
# Rule 30: ('Sparkling Water Natural Mango Essenced', 'Organic Pink Lemonade Bunny Fruit Snacks') -> ('Peach-Pear Sparkling Water',)
# Rule 31: ('Sparkling Water Natural Mango Essenced',) -> ('Peach-Pear Sparkling Water', 'Organic Pink Lemonade Bunny Fruit Snacks')
# Rule 32: ('Peach-Pear Sparkling Water', 'Sparkling Water Natural Mango Essenced', 'Dark Chocolate Minis') -> ('Organic Pink Lemonade Bunny Fruit Snacks',)
# Rule 33: ('Peach-Pear Sparkling Water', 'Sparkling Water Natural Mango Essenced', 'Organic Pink Lemonade Bunny Fruit Snacks') -> ('Dark Chocolate Minis',)
# Rule 34: ('Peach-Pear Sparkling Water', 'Dark Chocolate Minis', 'Organic Pink Lemonade Bunny Fruit Snacks') -> ('Sparkling Water Natural Mango Essenced',)
# Rule 35: ('Sparkling Water Natural Mango Essenced', 'Organic Pink Lemonade Bunny Fruit Snacks', 'Dark Chocolate Minis') -> ('Peach-Pear Sparkling Water',)
# Rule 36: ('Peach-Pear Sparkling Water', 'Sparkling Water Natural Mango Essenced') -> ('Dark Chocolate Minis', 'Organic Pink Lemonade Bunny Fruit Snacks')
# Rule 37: ('Peach-Pear Sparkling Water', 'Dark Chocolate Minis') -> ('Sparkling Water Natural Mango Essenced', 'Organic Pink Lemonade Bunny Fruit Snacks')
# Rule 38: ('Sparkling Water Natural Mango Essenced', 'Dark Chocolate Minis') -> ('Peach-Pear Sparkling Water', 'Organic Pink Lemonade Bunny Fruit Snacks')
# Rule 39: ('Sparkling Water Natural Mango Essenced', 'Organic Pink Lemonade Bunny Fruit Snacks') -> ('Peach-Pear Sparkling Water', 'Dark Chocolate Minis')

# %%
''' reading data '''
data_frame_test = pd.read_csv('https://raw.githubusercontent.com/aryan-jadon/Market-Basket-Item-Assignment/main/Dataset/testarules.csv')
data_frame_test.product_name = ["".join(i.split(",")) for i in data_frame_test]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Checking Test Dataset

# %%
data_frame_test
# Out:
#                   Item1                                     Item2  ... Item4  Item5
# 0  Dark Chocolate Minis  Organic Pink Lemonade Bunny Fruit Snacks  ...   NaN    NaN
#
# [1 rows x 5 columns]

# %% [markdown]
# ### Checking Support for Items present in test dataset

# %%
freq_itemset_using_apriori[ freq_itemset_using_apriori['itemsets'] == {'Dark Chocolate Minis'} ]
# Out:
#      support                itemsets
# 26  0.021157  (Dark Chocolate Minis)

# %%
freq_itemset_using_apriori[ freq_itemset_using_apriori['itemsets'] == {'Organic Pink Lemonade Bunny Fruit Snacks'} ]
# Out:
#      support                                    itemsets
# 97  0.020451  (Organic Pink Lemonade Bunny Fruit Snacks)

# %%
freq_itemset_using_apriori[ freq_itemset_using_apriori['itemsets'] == {'Peach-Pear Sparkling Water'} ]
# Out:
#       support                      itemsets
# 116  0.016925  (Peach-Pear Sparkling Water)
